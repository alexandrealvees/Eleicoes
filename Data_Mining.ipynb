# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandrealvees/Eleicoes/blob/master/Data_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_candidatos = pd.read_csv('https://raw.githubusercontent.com/alexandrealvees/Eleicoes/master/candidatos_DF.csv', encoding='latin1', sep=';')

# %%
# quantidade de candidatos]

df_candidatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1102 entries, 0 to 1101
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TP_ABRANGENCIA            1102 non-null   object
#  1   SG_UF                     1102 non-null   object
#  2   NM_UE                     1102 non-null   object
#  3   CD_CARGO                  1102 non-null   int64
#  4   DS_CARGO                  1102 non-null   object
#  5   SQ_CANDIDATO              1102 non-null   int64
#  6   NM_CANDIDATO              1102 non-null   object
#  7   NM_URNA_CANDIDATO         1102 non-null   object
#  8   CD_SITUACAO_CANDIDATURA   1102 non-null   int64
#  9   DS_SITUACAO_CANDIDATURA   1102 non-null   object
#  10  CD_DETALHE_SITUACAO_CAND  1102 non-null   int64
#  11  DS_DETALHE_SITUACAO_CAND  1102 non-null   object
#  12  TP_AGREMIACAO             1102 non-null   object
#  13  NR_PARTIDO                1102 non-null   int64
#  14  SG_PARTIDO                1102 non-null   object
#  15  NM_PARTIDO                1102 non-null   object
#  16  NM_COLIGACAO              1102 non-null   object
#  17  CD_NACIONALIDADE          1102 non-null   int64
#  18  DS_NACIONALIDADE          1102 non-null   object
#  19  NR_IDADE_DATA_POSSE       1102 non-null   int64
#  20  CD_GENERO                 1102 non-null   int64
#  21  DS_GENERO                 1102 non-null   object
#  22  CD_GRAU_INSTRUCAO         1102 non-null   int64
#  23  DS_GRAU_INSTRUCAO         1102 non-null   object
#  24  CD_ESTADO_CIVIL           1102 non-null   int64
#  25  DS_ESTADO_CIVIL           1102 non-null   object
#  26  CD_COR_RACA               1102 non-null   int64
#  27  DS_COR_RACA               1102 non-null   object
#  28  CD_OCUPACAO               1102 non-null   int64
#  29  DS_OCUPACAO               1102 non-null   object
#  30  CD_SIT_TOT_TURNO          1102 non-null   int64
#  31  DS_SIT_TOT_TURNO          1102 non-null   object
#  32  ST_REELEICAO              1102 non-null   object
#  33  VR_DESPESA_CONTRATADA     846 non-null    float64
#  34  QT_VOTOS_NOMINAIS         1102 non-null   int64
#  35  ELEITO                    1102 non-null   object
# dtypes: float64(1), int64(14), object(21)
# memory usage: 310.1+ KB

# %%
# Distribuição dos candidatos por faixa etária
plt.figure(figsize=(15,5))
#sns.distplot(cand[cand['DS_CARGO'] == 'DEPUTADO ESTADUAL']['NR_IDADE_DATA_POSSE'].dropna(), color='blue', label='DEPUTADO ESTADUAL')
#sns.distplot(cand[cand['DS_CARGO'] == 'DEPUTADO FEDERAL']['NR_IDADE_DATA_POSSE'].dropna(), color='green', label='DEPUTADO FEDERAL')
#sns.distplot(cand[cand['DS_CARGO'] == 'DEPUTADO DISTRITAL']['NR_IDADE_DATA_POSSE'].dropna(), color='red', label='DEPUTADO DISTRITAL')
sns.distplot(df_candidatos['NR_IDADE_DATA_POSSE'])
plt.title("Distribuição dos candidatos por faixa etária",color='black')
plt.grid(True,color="grey",alpha=.3)
#plt.legend(title="Cargo")
plt.xlabel('Idade na data da posse')
plt.ylabel('Distribuição')
plt.show()

# %%
# Distribuição dos candidatos por gênero
plt.figure(figsize=(15,8))
sns.countplot(x='DS_CARGO', hue='DS_GENERO', data=df_candidatos)
plt.grid(True,color="grey",alpha=.3)
plt.title("Quantidade de candidatos por gênero",color='black')
plt.legend(title="Sexo")
plt.xlabel('Cargo')
plt.ylabel("Quantidade de candidatos")
plt.show()

# %%
# Distribuição dos candidatos por raça
plt.figure(figsize=(10,5))
sns.countplot(x='DS_COR_RACA', data=df_candidatos)
plt.title("Quantidade de candidatos por raça",color='black')
plt.grid(True,color="grey",alpha=.3)
plt.xlabel('Raça')
plt.ylabel("Quantidade")
plt.show()

# %%
# Eleitos por partido
# Criaçã000000000000,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,SIT_TOT_TURNO = 1 ELEITO, 2 ELEITO POR QP e 3 ELEITO POR MÉDIA

ELEITO = []

for i in df_candidatos['CD_SIT_TOT_TURNO']:
    if i == 1:
        ELEITO.append('sim')
    elif i == 2:
        ELEITO.append('sim')
    elif i == 3:
        ELEITO.append('sim')
    else:
        ELEITO.append('nao')
        
df_candidatos['ELEITO'] = ELEITO

#df_eleito = df_candidatos[(df_candidatos.DS_SIT_TOT_TURNO == 'ELEITO POR MÉDIA')
#                         |(df_candidatos.DS_SIT_TOT_TURNO == 'ELEITO')
#                         |(df_candidatos.DS_SIT_TOT_TURNO == 'ELEITO POR QP')]
#cand = cand[(cand.CD_CARGO == 6) | (cand.CD_CARGO == 7) | (cand.CD_CARGO == 8)]

# %%
df_eleitos = df_candidatos[df_candidatos['ELEITO'] == 'sim']

plt.figure(figsize=(15,18))
sns.countplot(y='NM_PARTIDO', data=df_eleitos, order = df_eleitos['NM_PARTIDO'].value_counts().index)
plt.title("Eleitos por partido",color='black')
plt.grid(True,color="grey",alpha=.3)
plt.xlabel('Quantidade de votos')
plt.ylabel("Partido")
plt.show()
